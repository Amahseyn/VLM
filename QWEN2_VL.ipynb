# %%
# !pip install git+https://github.com/huggingface/transformers
# !pip install Pillow
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-ofhyzdmy
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-ofhyzdmy
#   Resolved https://github.com/huggingface/transformers to commit 16a3bea3b88e0530f78d4d7a2fcc0f6387ac72b9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers==5.2.0.dev0) (1.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==5.2.0.dev0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==5.2.0.dev0) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==5.2.0.dev0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==5.2.0.dev0) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==5.2.0.dev0) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers==5.2.0.dev0) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers==5.2.0.dev0) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==5.2.0.dev0) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.2.0.dev0) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.2.0.dev0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.2.0.dev0) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.2.0.dev0) (0.28.1)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.2.0.dev0) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.2.0.dev0) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.2.0.dev0) (4.15.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers==5.2.0.dev0) (8.3.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers==5.2.0.dev0) (13.9.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.2.0.dev0) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.2.0.dev0) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.2.0.dev0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.2.0.dev0) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.2.0.dev0) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer->transformers==5.2.0.dev0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer->transformers==5.2.0.dev0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers==5.2.0.dev0) (0.1.2)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-5.2.0.dev0-py3-none-any.whl size=11466288 sha256=20b5ab2f730c507b07b9497a2e735d4b2921820f3ee27115d1a21191e45f7e96
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pu1dkk_s/wheels/49/a7/50/c9fdabbf10e51bb1256adb0c1a587fedd7184f5bad28d47fe3
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# Successfully installed transformers-5.2.0.dev0
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)

# %%
from transformers import Qwen2VLForConditionalGeneration, AutoProcessor
from PIL import Image

# Load the model and processor
model = Qwen2VLForConditionalGeneration.from_pretrained("Qwen/Qwen2-VL-2B-Instruct", torch_dtype="auto", device_map="auto")
processor = AutoProcessor.from_pretrained("Qwen/Qwen2-VL-2B-Instruct")
image = Image.open("/content/stock_gs200.jpg")  # Replace with your image file
messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
            },
            {
                "type": "text",
                "text": "Analyse the image and extract texts"
            }
        ]
    }
]

text_prompt = processor.apply_chat_template(messages, add_generation_prompt=True)

inputs = processor(
    text=[text_prompt],
    images=[image],
    padding=True,
    return_tensors="pt"
)

inputs = inputs.to("cuda")  # Move to GPU if available

output_ids = model.generate(**inputs, max_new_tokens=1024)
generated_ids = [
    output_ids[len(input_ids):]
    for input_ids, output_ids in zip(inputs.input_ids, output_ids)
]

output_text = processor.batch_decode(
    generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True
)
print(output_text[0])
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/729 [00:00<?, ?it/s]
# The image contains the following text:
#
# **Nasdaq & AMEX**
#
# Stocks in bold rose or fell 5% or more
#
# Track your investments with our continuously updated stocks. Visit us on the web at
# money.usatoday.com
#
# 52-week High Low Stock Last Change
# - A
# - 9.19 6.89 ABX Air n 7.52 -0.10
# - 33.25 12.40 ACMoore 13.58 -1.57
# - 31.38 13.51 ADA-ES 20.96 +3.16
# - 27.14 12.88 ADC Tel rs 23.21 +0.13
# - 30.40 16.70 ADECp 27.32 +0.73
# - 16.45 10.47 AFC Ent s 15.40 -0.14
# - 8.37 4.50 ASE Tst 7.76 +0.40
# - 19.25 12.75 ASM Intl 17.65 -0.03
# - 20.92 13.94 ASML Hld 21.24 +0.46
# - 27.38 16.39 ASV Inc s 27.66 +0.14
# - 19.82 10.47 AFC Ent s 17.89 +0.68
# - 33.62 20.53 ATi Tech 29.95 +1.29
# - 39.20 16.76 AVI Bio 38.40 -0.59
# - 4.24 1.99 AVI Bio 3.62 -0.02
# - 20.55 11.80 AVI Bio 4.55 +0.01
# - 46.72 26.65 AVI Bio 47.00 +0.03
# - 50.55 11.80 AVI Bio 50.55 +0.03
#
# **USA TODAY**
#
# 52-week High Low Stock Last Change
# - A
# - 9.19 6.89 ABX Air n 7.52 -0.10
# - 33.25 12.40 ACMoore 13.58 -1.57
# - 31.38 13.51 ADA-ES 20.96 +3.16
# - 27.14 12.88 ADC Tel rs 23.21 +0.13
# - 30.40 16.70 ADECp 27.32 +0.73
# - 16.45 10.47 AFC Ent s 15.40 -0.14
# - 8.37 4.50 ASE Tst 7.76 +0.40
# - 19.25 12.75 ASM Intl 17.65 -0.03
# - 20.92 13.94 ASML Hld 21.24 +0.46
# - 27.38 16.39 ASV Inc s 27.66 +0.14
# - 19.82 10.47 AFC Ent s 17.89 +0.68
# - 33.62 20.53 ATi Tech 29.95 +1.29
# - 39.20 16.76 AVI Bio 38.40 -0.59
# - 4.24 1.99 AVI Bio 3.62 -0.02
# - 20.55 11.80 AVI Bio 4.55 +0.01
# - 46.72 26.65 AVI Bio 47.00 +0.03
# - 50.55 11.80 AVI Bio 50.55 +0.03
#
# **AMEX**
#
# Stocks in bold rose or
